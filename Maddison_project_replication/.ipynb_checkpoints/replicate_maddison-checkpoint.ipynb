# %% [markdown]
# # Largest falls in real GDP in (currently) advanced economies since 1870
#
# This is a replication exercise using the `data.table` package in R and the Maddison Database. The graph to replicate is:

# %% [markdown]
# ![title](cost.jpg)

# %%
library(data.table)

# %%
df <- read.csv("Maddision-project.csv", stringsAsFactors = FALSE)
head(df, 10)
# Out:
#    countrycode country     year cgdppc rgdpnapc pop  i_cig        i_bm
# 1  AFG         Afghanistan 1820   NA     NA     3280
# 2  AFG         Afghanistan 1870   NA     NA     4207
# 3  AFG         Afghanistan 1913   NA     NA     5730
# 4  AFG         Afghanistan 1950 2392   2392     8150 Extrapolated
# 5  AFG         Afghanistan 1951 2422   2422     8284 Extrapolated
# 6  AFG         Afghanistan 1952 2462   2462     8425 Extrapolated
# 7  AFG         Afghanistan 1953 2568   2568     8573 Extrapolated
# 8  AFG         Afghanistan 1954 2576   2576     8728 Extrapolated
# 9  AFG         Afghanistan 1955 2579   2579     8891 Extrapolated
# 10 AFG         Afghanistan 1956 2644   2644     9062 Extrapolated

# %% [markdown]
# Note: The Maddison Project has two time series, `rgdpnapc` and `cgdppc`. The first one is purely within-country data, with the international price comparison done once (in 2011). The second series coerces the GDP data to fit every international price comparison the Maddison Project has on record. For this purpose we will use `rgdpnapc`.

# %%
dt <- data.table(df[df$countrycode != "",c("countrycode", "country", "year", "rgdpnapc")])

# %% [markdown]
# Create a gdp growth variable from 1 to 10 years

# %%
for (i in 1:10) {
    dt[, paste0("diff_",i) := (rgdpnapc - shift(rgdpnapc, i))/shift(rgdpnapc,i), by = countrycode]
}

# %% [markdown]
# Explore

# %%
head(dt, 10)
# Out:
#    countrycode country     year rgdpnapc diff_1      diff_2      diff_3
# 1  AFG         Afghanistan 1820   NA              NA          NA         NA
# 2  AFG         Afghanistan 1870   NA              NA          NA         NA
# 3  AFG         Afghanistan 1913   NA              NA          NA         NA
# 4  AFG         Afghanistan 1950 2392              NA          NA         NA
# 5  AFG         Afghanistan 1951 2422     0.012541806          NA         NA
# 6  AFG         Afghanistan 1952 2462     0.016515277 0.029264214         NA
# 7  AFG         Afghanistan 1953 2568     0.043054427 0.060280760 0.07357860
# 8  AFG         Afghanistan 1954 2576     0.003115265 0.046303818 0.06358382
# 9  AFG         Afghanistan 1955 2579     0.001164596 0.004283489 0.04752234
# 10 AFG         Afghanistan 1956 2644     0.025203567 0.026397516 0.02959502
#    diff_4     diff_5     diff_6    diff_7 diff_8 diff_9 diff_10
# 1          NA         NA        NA NA     NA     NA     NA
# 2          NA         NA        NA NA     NA     NA     NA
# 3          NA         NA        NA NA     NA     NA     NA
# 4          NA         NA        NA NA     NA     NA     NA
# 5          NA         NA        NA NA     NA     NA     NA
# 6          NA         NA        NA NA     NA     NA     NA
# 7          NA         NA        NA NA     NA     NA     NA
# 8  0.07692308         NA        NA NA     NA     NA     NA
# 9  0.06482246 0.07817726        NA NA     NA     NA     NA
# 10 0.07392364 0.09165979 0.1053512 NA     NA     NA     NA

# %% [markdown]
# Create sub-table with only country and differences

# %%
sub_dt <- dt[, .(country, diff_1, diff_2, diff_3, diff_4, diff_5,
              diff_6, diff_7, diff_8, diff_9, diff_10)]

# %%
head(sub_dt)
# Out:
#   country     diff_1     diff_2     diff_3 diff_4 diff_5 diff_6 diff_7 diff_8
# 1 Afghanistan         NA         NA NA     NA     NA     NA     NA     NA
# 2 Afghanistan         NA         NA NA     NA     NA     NA     NA     NA
# 3 Afghanistan         NA         NA NA     NA     NA     NA     NA     NA
# 4 Afghanistan         NA         NA NA     NA     NA     NA     NA     NA
# 5 Afghanistan 0.01254181         NA NA     NA     NA     NA     NA     NA
# 6 Afghanistan 0.01651528 0.02926421 NA     NA     NA     NA     NA     NA
#   diff_9 diff_10
# 1 NA     NA
# 2 NA     NA
# 3 NA     NA
# 4 NA     NA
# 5 NA     NA
# 6 NA     NA

# %% [markdown]
# Get the largest fall per country

# %%
sub_dt <- sub_dt[, lapply(.SD, min, na.rm = TRUE), by = country]

# %%
head(sub_dt)
# Out:
#   country              diff_1     diff_2     diff_3     diff_4     diff_5
# 1 Afghanistan          -0.3370166 -0.5260896 -0.5616127 -0.6124498 -0.6265119
# 2 Angola               -0.2629687 -0.3251822 -0.3371738 -0.3482081 -0.3370179
# 3 Albania              -0.2656040 -0.2943422 -0.2879474 -0.2825839 -0.2779692
# 4 United Arab Emirates -0.1514626 -0.2373265 -0.3228744 -0.3633580 -0.4004127
# 5 Argentina            -0.2128909 -0.1706620 -0.1997317 -0.2652174 -0.2852559
# 6 Armenia              -0.4046754 -0.4831527 -0.5316256 -0.5696959 -0.5280594
#   diff_6     diff_7     diff_8     diff_9     diff_10
# 1 -0.6614035 -0.6920622 -0.7222022 -0.7140741 -0.7208966
# 2 -0.3365498 -0.2756598 -0.2771739 -0.2738279 -0.2871336
# 3 -0.2734628 -0.2688997 -0.2651391 -0.2608184 -0.2566225
# 4 -0.4362605 -0.4367274 -0.4366152 -0.4428697 -0.4621449
# 5 -0.2551672 -0.2699240 -0.2456518 -0.2370797 -0.2160400
# 6 -0.5373686 -0.5643328 -0.5681323 -0.5551188 -0.5409424

# %%
largest_fall <- cbind(sub_dt[,c("country")], apply(sub_dt[,-1], 1, min))

# %%
names(largest_fall) <- c("country", "gdp_fall")
head(largest_fall)
# Out:
#   country              gdp_fall
# 1 Afghanistan          -0.7222022
# 2 Angola               -0.3482081
# 3 Albania              -0.2943422
# 4 United Arab Emirates -0.4621449
# 5 Argentina            -0.2852559
# 6 Armenia              -0.5696959

# %%
largest_fall[,c("year", "number_years")] <- numeric()

# %%
head(largest_fall)
# Out:
#   country              gdp_fall   year number_years
# 1 Afghanistan          -0.7222022 NA   NA
# 2 Angola               -0.3482081 NA   NA
# 3 Albania              -0.2943422 NA   NA
# 4 United Arab Emirates -0.4621449 NA   NA
# 5 Argentina            -0.2852559 NA   NA
# 6 Armenia              -0.5696959 NA   NA

# %%
largest_fall[country == "Afghanistan", 3] <- 1

# %%
for (eachcountry in largest_fall$country) {
    tmp <- dt[country == eachcountry]
    loc <- which(tmp == largest_fall[country == eachcountry, gdp_fall], arr.ind = TRUE)
    tmp <- cbind(tmp[loc[1], c(2,3)],loc[2] - 4)
    names(tmp) <- c("country", "year", "number_years")
    largest_fall[country == eachcountry, 3] <- tmp$year
    largest_fall[country == eachcountry, 4] <- tmp$number_years
}

# %%
head(largest_fall)
# Out:
#   country              gdp_fall   year number_years advanced
# 1 Afghanistan          -0.7222022 1994  8           FALSE
# 2 Angola               -0.3482081 1994  4           FALSE
# 3 Albania              -0.2943422 1992  2           FALSE
# 4 United Arab Emirates -0.4621449 2010 10           FALSE
# 5 Argentina            -0.2852559 1917  5           FALSE
# 6 Armenia              -0.5696959 1993  4           FALSE

# %% [markdown]
# List of currently advanced economies by the IMF:

# %%
advanced_economies = c("Australia",
"Austria",
"Belgium",
"Canada",
"Cyprus",
"Czech Republic",
"Denmark",
"Estonia",
"Finland",
"France",
"Germany",
"Greece",
"China, Hong Kong SAR",
"Iceland",
"Ireland",
"Israel",
"Italy",
"Japan",
"Republic of Korea",
"Latvia",
"Lithuania",
"Luxembourg",
"Macao SAR",
"Malta",
"Netherlands",
"New Zealand",
"Norway",
"Portugal",
"Puerto Rico",
"San Marino",
"Singapore",
"Slovakia",
"Slovenia",
"Spain",
"Sweden",
"Switzerland",
"Taiwan, Province of China",
"United Kingdom",
"United States")

# %%
largest_fall$advanced <- ifelse(largest_fall$country %in% advanced_economies, TRUE, FALSE)

# %%
head(largest_fall)
# Out:
#   country              gdp_fall   year number_years advanced
# 1 Afghanistan          -0.7222022 1994  8           FALSE
# 2 Angola               -0.3482081 1994  4           FALSE
# 3 Albania              -0.2943422 1992  2           FALSE
# 4 United Arab Emirates -0.4621449 2010 10           FALSE
# 5 Argentina            -0.2852559 1917  5           FALSE
# 6 Armenia              -0.5696959 1993  4           FALSE

# %%
largest_fall$period <- paste0(largest_fall$year - largest_fall$number_years, " - ", largest_fall$year)

# %%
final <- largest_fall[order(rank(gdp_fall))][advanced == TRUE, .(country, period, gdp_fall)]

# %%
par(mar=c(4,20,4,4))
options(repr.plot.width=15, repr.plot.height=10)
bp <- barplot(head(final$gdp_fall * 100,20), horiz = TRUE, col = 'red', 
        main = "Largest falls in real GDP in currently advanced economies since 1870",
       names.arg = paste(head(final$country,20),head(final$period,20)), las=1, cex.axis = 1.5, cex.main = 2,
       cex.names = 1.5)
text(head(final$gdp_fall * 100,20) + 2, bp, 
     paste0(signif(head(final$gdp_fall * 100,20),2),"%"), col = "white", cex = 1.2, font = 2)
# Out:
# Plot with title “Largest falls in real GDP in currently advanced economies since 1870”
